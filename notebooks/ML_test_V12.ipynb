# %%
# Ejemplo de Arboles de decisión
# Importar librerías 

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import  accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
# Ruta del dataset
file_path = "C:/Git/vehicles_env/datasets/Electrical_Grid_Stability_us.csv"

# Cargar dataframe
electrical_grid = pd.read_csv(file_path, sep=';')

print('Tamaño del dataframe:', electrical_grid.shape)
#print(electrical_grid.head())

print('La relación entre las clases: \n', electrical_grid['stability'].value_counts())
# Out:
# Tamaño del dataframe: (10000, 13)
# La relación entre las clases:
#  stability
# 0    6380
# 1    3620
# Name: count, dtype: int64

# %%
# Divide los datos en características (la matriz X) y una variable objetivo (y)
X = electrical_grid.drop('stability', axis = 1)
y = electrical_grid['stability']

# Dividir los datos de entrenamiento (train) y datos de prueba (test)
# Especificar que el tamaño de los datos para prueba será el 20% de los registros
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Especificar el tipo de modelo
model = LogisticRegression(random_state=0)

# Entrenar el modelo con los conjuntos de entrenamiento (train)
model.fit(X_train, y_train)

# Estima la probabilidad de que un objeto entre en la segunda clase (1)
probabilities = model.predict_proba(X_test)[:,1]

# Predicción para los datos de pruba
predictions = model.predict(X_test)

# muestra todas las métricas estudiadas
print('Métricas de regresión logística')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, predictions)))
print('ROC_AUC: {:.2f}\n'.format(roc_auc_score(y_test, probabilities)))

# Crear el modelo de arbol de decisión
tree_model = DecisionTreeClassifier(random_state=0)

# Entrenar el arbol
tree_model.fit(X_train, y_train)

# Crear predicciones y probabilidades
tree_predictions = tree_model.predict(X_test)
tree_probabilities = tree_model.predict_proba(X_test)[:,1]

# Mostrar las métricas del árbol de decisión.
print('Métricas del árbol de decisión')
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, tree_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, tree_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, tree_predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, tree_predictions)))
print('ROC_AUC: {:.2f}'.format(roc_auc_score(y_test, tree_probabilities)))
# Out:
# Métricas de regresión logística
# Accuracy: 0.81
# Precision: 0.77
# Recall: 0.70
# F1: 0.73
# ROC_AUC: 0.89
#
# Métricas del árbol de decisión
# Accuracy: 0.83
# Precision: 0.77
# Recall: 0.77
# F1: 0.77
# ROC_AUC: 0.82

# %% [markdown]
# ¡Es correcto!
#
# Desafortunadamente, ¡nada cambió! Aunque el árbol de decisión es más fácil de interpretar, su roc_auc reveló que es aún menos adecuado para esta tarea que la regresión lineal, al menos con los parámetros predeterminados. ¿Cómo podemos mejorar las métricas? ¡Con algoritmos más poderosos, por supuesto!
